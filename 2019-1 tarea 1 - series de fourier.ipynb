# %% [markdown]
# # Tarea 1
# ## Resuelva los siguientes problemas (Series de Fourier)
# Obtenga la representación en series de Fourier de las siguientes funciones.
#
#
# * $f(t) = t$, en el rango $-\pi < t < \pi$
#
#
# * $f(t) = |t|$, en el rango $-\pi < t < \pi$
#
#
# * $f(t) = t^2$, en el rango $-\pi < t < \pi$
#
# Puede realizar los cálculos manuales o utilizar herramientas de CAS (como Sympy) para realizar sus cálculos.

# %%
a = 2
