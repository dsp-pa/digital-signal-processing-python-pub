# %% [markdown]
# # Laboratorio 2 – Señales digitales

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.misc

s = scipy.misc.electrocardiogram()
# Out:
# C:\Users\rober\AppData\Local\Temp\ipykernel_5068\1333479162.py:5: DeprecationWarning: scipy.misc.electrocardiogram has been deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. Dataset methods have moved into the scipy.datasets module. Use scipy.datasets.electrocardiogram instead.
#   s = scipy.misc.electrocardiogram()

# %%
plt.plot(s)

# %%
t = np.linspace(0, 300, len(s))

# %%
plt.plot(t, s)

# %%
plt.plot(t, s)
plt.grid()

# %%
plt.plot(t, s)
plt.grid()
plt.xlim(200, 225)
# Out:
# (200.0, 225.0)
